# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanashri9898/Dhanashri-A-Patil/blob/main/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1) Find greatest of three numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Greatest number =", a)
elif b >= a and b >= c:
    print("Greatest number =", b)
else:
    print("Greatest number =", c)


# 2) Check even or odd
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")


# 3) Check uppercase / lowercase / not alphabet
ch = input("Enter a character: ")

if ch.isalpha():
    if ch.isupper():
        print("Uppercase letter")
    else:
        print("Lowercase letter")
else:
    print("Not an alphabet")


# 4) Check number or character
ch = input("Enter any input: ")

if ch.isdigit():
    print("It is a number")
else:
    print("It is a character")
# Out:
# Enter first number: 98
# Enter second number: 98
# Enter third number: 1
# Greatest number = 98
# Enter a number: 23
# Odd number
# Enter a character: Shree
# Lowercase letter
# Enter any input: Fidi
# It is a character
